# %%
from PIL import Image
import os
import random
import matplotlib.pyplot as plt

# %%
os.chdir("../")

# %%
pwd
# Out:
# 'g:\\food-classification-CNNs-project-scratch'

# %%
image_files = []
for root, dirs, files in os.walk("data/processed/train"):
    for file in files:
            image_files.append(os.path.join(root, file))

# %%
image_file_select = random.sample(image_files, 20)

# %%
image_file_select
# Out:
# ['data/processed/train\\french_fries\\frenchfries84.jpg',
#  'data/processed/train\\french_fries\\frenchfries45.jpg',
#  'data/processed/train\\haleem\\haleem83.jpg',
#  'data/processed/train\\brownie\\brownie70.jpg',
#  'data/processed/train\\omelette\\omelette35.jpg',
#  'data/processed/train\\omelette\\omelette32.jpg',
#  'data/processed/train\\chai\\chai30.jpg',
#  'data/processed/train\\omelette\\omelette4.jpg',
#  'data/processed/train\\biryani\\biryani0.jpg',
#  'data/processed/train\\fried_rice\\friedrice88.jpg',
#  'data/processed/train\\biryani\\biryani1.jpg',
#  'data/processed/train\\fried_rice\\friedrice83.jpg',
#  'data/processed/train\\biryani\\biryani84.jpg',
#  'data/processed/train\\butter_chicken\\butterchicken43.jpg',
#  'data/processed/train\\chicken_tikka\\chickentikka24.jpg',
#  'data/processed/train\\brownie\\brownie39.jpg',
#  'data/processed/train\\french_fries\\frenchfries89.jpg',
#  'data/processed/train\\samosa\\samosa35.jpg',
#  'data/processed/train\\bbq\\bbq65.jpg',
#  'data/processed/train\\butter_chicken\\butterchicken118.jpg']

# %%
fig, axes = plt.subplots(ncols=2,nrows=10, sharex=True, sharey=True)

for i, ax in enumerate(axes.flat):
    ax.imshow(Image.open(image_file_select[i]))
    ax.axis('off')
    ax.set_title(os.path.basename(image_file_select[i]))
plt.show()

# %%
import torch

# %%
x = torch.randn(4, 4)

# %%
x
# Out:
# tensor([[ 1.1997, -1.1998, -0.0757,  0.7792],
#         [ 0.2144, -0.0031,  0.9951, -0.8200],
#         [-0.8099,  0.9165,  0.0441, -0.0607],
#         [-0.8241, -1.9919, -1.3847,  3.1279]])

# %%
y = x.view(-1, 8)

# %%
x.shape
# Out:
# torch.Size([4, 4])

# %%
y
# Out:
# tensor([[ 1.1997, -1.1998, -0.0757,  0.7792,  0.2144, -0.0031,  0.9951, -0.8200],
#         [-0.8099,  0.9165,  0.0441, -0.0607, -0.8241, -1.9919, -1.3847,  3.1279]])

# %%
y.shape
# Out:
# torch.Size([2, 8])
